# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("airline_data.csv")

# %%
df
# Out:
#         Airline     Source Destination            Class Flight_Status  \
# 0       Vistara      Delhi     Lucknow            First       Delayed
# 1        IndiGo      Delhi         Goa          Economy           NaN
# 2      SpiceJet    Kolkata      Jaipur         Business           NaN
# 3     Air India  Bangalore        Pune          Economy   Rescheduled
# 4        IndiGo    Chennai   Ahmedabad  Premium Economy       Delayed
# ...         ...        ...         ...              ...           ...
# 4995    Vistara        NaN        Pune         Business   Rescheduled
# 4996   SpiceJet     Mumbai  Chandigarh         Business     Cancelled
# 4997  Air India  Bangalore         Goa            First       On Time
# 4998  Air India  Hyderabad  Chandigarh         Business       Delayed
# 4999   SpiceJet  Hyderabad         Goa         Business       On Time
#
#      Aircraft_Type  Booking_Channel Meal_Preference Passenger_Gender  \
# 0            ATR72  Airport Counter         Non-Veg            Other
# 1             A321            Agent             Veg           Female
# 2             B777           Online             Veg            Other
# 3            ATR72       Mobile App         No Meal             Male
# 4             B737            Agent         Non-Veg             Male
# ...            ...              ...             ...              ...
# 4995          A321       Mobile App             Veg            Other
# 4996         ATR72           Online         Non-Veg           Female
# 4997          A320       Mobile App             Veg            Other
# 4998           NaN            Agent         Non-Veg             Male
# 4999          B737            Agent             Veg             Male
#
#       Flight_Duration_Minutes  Ticket_Price  Passenger_Age  Baggage_Weight_Kg  \
# 0                       244.0       12104.0           73.0              35.22
# 1                       121.0       13279.0           32.0              39.28
# 2                       135.0        5239.0           53.0              44.59
# 3                       339.0        7539.0           38.0               8.34
# 4                       276.0        5364.0            NaN              39.87
# ...                       ...           ...            ...                ...
# 4995                    186.0       21301.0           56.0              18.03
# 4996                      NaN       15993.0           71.0              30.78
# 4997                    356.0       17817.0            NaN              22.40
# 4998                      NaN       11070.0           35.0              28.36
# 4999                    344.0       16066.0           28.0              31.44
#
#       Seat_Number  Distance_Km  Delay_Minutes  Loyalty_Points  \
# 0           160.0       1459.0           35.0          5368.0
# 1           179.0       1330.0          128.0          7614.0
# 2           147.0       1230.0            NaN          3952.0
# 3           121.0        839.0           99.0          4738.0
# 4             9.0        706.0           35.0           216.0
# ...           ...          ...            ...             ...
# 4995        131.0        738.0          142.0          7766.0
# 4996         56.0        816.0          176.0          3162.0
# 4997         63.0       1595.0          161.0          3828.0
# 4998        144.0       1043.0          123.0          4251.0
# 4999         40.0        783.0           40.0          2724.0
#
#       Extra_Luggage_Fee  Rating_Out_of_5
# 0                   NaN              4.8
# 1                1190.0              1.0
# 2                2326.0              NaN
# 3                1099.0              NaN
# 4                1227.0              4.1
# ...                 ...              ...
# 4995                NaN              3.9
# 4996             3552.0              NaN
# 4997             4076.0              1.4
# 4998              603.0              3.5
# 4999             4862.0              4.2
#
# [5000 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# Airline                    249
# Source                     247
# Destination                258
# Class                      249
# Flight_Status              242
# Aircraft_Type              247
# Booking_Channel            254
# Meal_Preference            252
# Passenger_Gender           250
# Flight_Duration_Minutes    251
# Ticket_Price               249
# Passenger_Age              249
# Baggage_Weight_Kg          250
# Seat_Number                254
# Distance_Km                251
# Delay_Minutes              250
# Loyalty_Points             247
# Extra_Luggage_Fee          251
# Rating_Out_of_5            254
# dtype: int64

# %%
df["Airline"] = df["Airline"].fillna(df["Airline"].mode()[0])

# %%
df["Source"] = df["Source"].fillna(df["Source"].mode()[0])

# %%
df["Destination"] = df["Destination"].fillna(df["Destination"].mode()[0])

# %%
df["Class"] = df["Class"].fillna(df["Class"].mode()[0])

# %%
df["Booking_Channel"] = df["Booking_Channel"].fillna("Unknown")

# %%
df["Passenger_Gender"] = df["Passenger_Gender"].fillna(df["Passenger_Gender"].mode()[0])

# %%
df["Flight_Duration_Minutes"] = df["Flight_Duration_Minutes"].fillna(df["Flight_Duration_Minutes"].mean())

# %%
df["Ticket_Price"] = df["Ticket_Price"].fillna(df["Ticket_Price"].mean())

# %%
df["Passenger_Age"] = df["Passenger_Age"].fillna(df["Passenger_Age"].median())

# %%
df["Baggage_Weight_Kg"] = df["Baggage_Weight_Kg"].fillna(df["Baggage_Weight_Kg"].median())

# %%
df["Distance_Km"] = df["Distance_Km"].fillna(df["Distance_Km"].mean())

# %%
df["Rating_Out_of_5"] = df["Rating_Out_of_5"].fillna(df["Rating_Out_of_5"].mean())

# %%
df.isnull().sum()
# Out:
# Airline                      0
# Source                       0
# Destination                  0
# Class                        0
# Flight_Status              242
# Aircraft_Type              247
# Booking_Channel              0
# Meal_Preference            252
# Passenger_Gender             0
# Flight_Duration_Minutes      0
# Ticket_Price                 0
# Passenger_Age                0
# Baggage_Weight_Kg            0
# Seat_Number                254
# Distance_Km                  0
# Delay_Minutes              250
# Loyalty_Points             247
# Extra_Luggage_Fee          251
# Rating_Out_of_5              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Airline                  5000 non-null   str
#  1   Source                   5000 non-null   str
#  2   Destination              5000 non-null   str
#  3   Class                    5000 non-null   str
#  4   Flight_Status            4758 non-null   str
#  5   Aircraft_Type            4753 non-null   str
#  6   Booking_Channel          5000 non-null   str
#  7   Meal_Preference          4748 non-null   str
#  8   Passenger_Gender         5000 non-null   str
#  9   Flight_Duration_Minutes  5000 non-null   float64
#  10  Ticket_Price             5000 non-null   float64
#  11  Passenger_Age            5000 non-null   float64
#  12  Baggage_Weight_Kg        5000 non-null   float64
#  13  Seat_Number              4746 non-null   float64
#  14  Distance_Km              5000 non-null   float64
#  15  Delay_Minutes            4750 non-null   float64
#  16  Loyalty_Points           4753 non-null   float64
#  17  Extra_Luggage_Fee        4749 non-null   float64
#  18  Rating_Out_of_5          5000 non-null   float64
# dtypes: float64(10), str(9)
# memory usage: 742.3 KB

# %%
df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Class', 'Flight_Status',
#        'Aircraft_Type', 'Booking_Channel', 'Meal_Preference',
#        'Passenger_Gender', 'Flight_Duration_Minutes', 'Ticket_Price',
#        'Passenger_Age', 'Baggage_Weight_Kg', 'Seat_Number', 'Distance_Km',
#        'Delay_Minutes', 'Loyalty_Points', 'Extra_Luggage_Fee',
#        'Rating_Out_of_5'],
#       dtype='str')

# %%
df["Flight_Status"] = df["Flight_Status"].fillna(df["Flight_Status"].mode()[0])

# %%
df["Aircraft_Type"] = df["Aircraft_Type"].fillna(df["Aircraft_Type"].mode()[0])

# %%
df["Meal_Preference"] = df["Meal_Preference"].fillna("No Meal")

# %%
a = np.random.randint(50,123)
df["Seat_Number"] = df["Seat_Number"].fillna(a)

# %%
df["Delay_Minutes"] = df["Delay_Minutes"].fillna(df["Delay_Minutes"].mean())

# %%
b = np.random.randint(3000,5400)
df["Loyalty_Points"] = df["Loyalty_Points"].fillna(b)

# %%
df["Extra_Luggage_Fee"] = df["Extra_Luggage_Fee"].fillna(b)

# %%
df.isnull().sum()
# Out:
# Airline                    0
# Source                     0
# Destination                0
# Class                      0
# Flight_Status              0
# Aircraft_Type              0
# Booking_Channel            0
# Meal_Preference            0
# Passenger_Gender           0
# Flight_Duration_Minutes    0
# Ticket_Price               0
# Passenger_Age              0
# Baggage_Weight_Kg          0
# Seat_Number                0
# Distance_Km                0
# Delay_Minutes              0
# Loyalty_Points             0
# Extra_Luggage_Fee          0
# Rating_Out_of_5            0
# dtype: int64

# %%
df.to_csv("clean_data_airline.csv",index = False)

# %% [markdown]
# ### Graphs

# %%
a = df["Passenger_Gender"].value_counts()

# %%
a
# Out:
# Passenger_Gender
# Other     1875
# Female    1590
# Male      1535
# Name: count, dtype: int64

# %%
a = df["Passenger_Gender"].value_counts()

plt.bar(a.index, a.values)
plt.title("Passanger Count")
plt.show()

# %%
a = df.groupby("Airline")["Passenger_Gender"].count().plot(kind="pie",autopct = "%.4f")

#plt.barh(a.index, a.values)
plt.show()

# %%
plt.hist(df["Passenger_Age"], bins=30) 
# bins - bydefault 10 
# more bins= precised graph
plt.show()

# %%
sns.histplot(df["Distance_Km"], kde=True)
plt.show()

# %%
sns.barplot(x = df["Booking_Channel"],y = df["Seat_Number"],hue=df["Booking_Channel"])
plt.show()

# %%
plt.bar(df["Source"],df["Delay_Minutes"].mean())
# Out:
# <BarContainer object of 5000 artists>

# %%
a = df.groupby("Airline")["Delay_Minutes"].median()

#plt.barh(a.index, a.values)
#plt.show()
a
# Out:
# Airline
# Air India       89.957895
# Akasa Air       89.957895
# Alliance Air    91.000000
# IndiGo          89.957895
# SpiceJet        89.957895
# Vistara         89.957895
# Name: Delay_Minutes, dtype: float64

# %%
plt.barh(df["Class"],df["Ticket_Price"].mean())
# Out:
# <BarContainer object of 5000 artists>

# %%
a = df.groupby("Class")["Ticket_Price"].mean()

#plt.barh(a.index, a.values)
#plt.show()
a
# Out:
# Class
# Business           16272.360298
# Economy            16465.423670
# First              15630.248349
# Premium Economy    16571.688609
# Name: Ticket_Price, dtype: float64

# %%
sns.violinplot(x="Class", y="Ticket_Price",hue="Class" ,data = df)
plt.show()

# %%
# #Correlation Heatmap :- Correlation tells us how strongly two numeric variables are related
# corr = df.corr(numeric_only=True)
# sns.heatmap(corr, annot=True, cmap="coolwarm")
# plt.Figure(figsize=(30,10))
# plt.show()

# %%
#sns.pairplot(df)

# %%
#plt.plot(df["Aircraft_Type"],df["Passenger_Gender"])

# %%
#using pandas
flight=df.groupby("Flight_Status")["Airline"].count().reset_index()

# %%
# sns.lineplot(x= flight["Flight_Status"], y=flight["Airline"],marker="p",color = "red")
# plt.rcParams['figure.facecolor'] = 'lightblue'
# plt.rcParams['axes.facecolor'] = 'lightyellow'

# %%
fig, ax = plt.subplots()

fig.patch.set_facecolor("lightgray")
ax.set_facecolor("lightyellow")

ax.plot(flight["Flight_Status"], flight["Airline"],marker="p",color = "red")
plt.show()

# %%
df.groupby("Meal_Preference")["Passenger_Gender"].count()
# Out:
# Meal_Preference
# No Meal    1436
# Non-Veg    1106
# Veg        1270
# Vegan      1188
# Name: Passenger_Gender, dtype: int64

# %%
plt.bar(df["Meal_Preference"],df["Passenger_Gender"].count())
# Out:
# <BarContainer object of 5000 artists>
